# %%
# %cd "/home/hatlab/QutipSimulation/HaPiCodes/HaPiCodes/test_examples"
# Out:
# /home/hatlab/QutipSimulation/HaPiCodes/HaPiCodes/test_examples

# %%
amp_size_list = [100, 400, 700, 1000]

# %% [markdown]
# # Hatlab-tower

# %%
# %timeit -r1 -n1 %run S001_piPulseTuneUp.py 100
# %timeit -r1 -n1 %run S001_piPulseTuneUp.py 400
# %timeit -r1 -n1  %run S001_piPulseTuneUp.py 700
# %timeit -r1 -n1  %run S001_piPulseTuneUp.py 1000
# Out:
# 10.0%. Run time:   0.73s. Est. time left: 00:00:00:06
# 20.0%. Run time:   1.09s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.41s. Est. time left: 00:00:00:03
# 40.0%. Run time:   1.72s. Est. time left: 00:00:00:02
# 50.0%. Run time:   1.97s. Est. time left: 00:00:00:01
# 60.0%. Run time:   2.39s. Est. time left: 00:00:00:01
# 70.0%. Run time:   2.74s. Est. time left: 00:00:00:01
# 80.0%. Run time:   3.02s. Est. time left: 00:00:00:00
# 90.0%. Run time:   3.38s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.71s. Est. time left: 00:00:00:00
# Total run time:   3.73s
# The rotation angle is 0.0 pi
# Pi pulse amp is  0.12889573584688296 V
# The Excited State DAC is 1.01
# The Ground State DAC is 0.01
# info successly stored
# 4.99 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 10.0%. Run time:   5.33s. Est. time left: 00:00:00:47
# 20.0%. Run time:  10.33s. Est. time left: 00:00:00:41
# 30.0%. Run time:  15.33s. Est. time left: 00:00:00:35
# ...

# %% [markdown]
# # Pinlei's Lab Computer

# %%
# %timeit -r1 -n1 %run S001_piPulseTuneUp.py 100
# Out:
# 10.0%. Run time:   6.22s. Est. time left: 00:00:00:55
# 20.0%. Run time:   6.70s. Est. time left: 00:00:00:26
# 30.0%. Run time:   7.17s. Est. time left: 00:00:00:16
# 40.0%. Run time:   7.66s. Est. time left: 00:00:00:11
# 50.0%. Run time:   8.05s. Est. time left: 00:00:00:08
# 60.0%. Run time:   8.61s. Est. time left: 00:00:00:05
# 70.0%. Run time:   9.09s. Est. time left: 00:00:00:03
# 80.0%. Run time:   9.57s. Est. time left: 00:00:00:02
# 90.0%. Run time:  10.04s. Est. time left: 00:00:00:01
# 100.0%. Run time:  10.49s. Est. time left: 00:00:00:00
# Total run time:  10.62s
# The rotation angle is 0.0 pi
# Pi pulse amp is  0.12889573584834585 V
# The Excited State DAC is 1.01
# The Ground State DAC is 0.01
# info successly stored
# 12.3 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %% [markdown]
# # Evan's Laptop

# %%
# %timeit -r1 -n1 %run S001_piPulseTuneUp.py 100
# %timeit -r1 -n1 %run S001_piPulseTuneUp.py 400
# %timeit -r1 -n1  %run S001_piPulseTuneUp.py 700
# %timeit -r1 -n1  %run S001_piPulseTuneUp.py 1000
# Out:
# 10.0%. Run time:   1.96s. Est. time left: 00:00:00:17
# 20.0%. Run time:   3.36s. Est. time left: 00:00:00:13
# 30.0%. Run time:   5.12s. Est. time left: 00:00:00:11
# 40.0%. Run time:   6.40s. Est. time left: 00:00:00:09
# 50.0%. Run time:   7.74s. Est. time left: 00:00:00:07
# 60.0%. Run time:   9.21s. Est. time left: 00:00:00:06
# 70.0%. Run time:  10.78s. Est. time left: 00:00:00:04
# 80.0%. Run time:  12.34s. Est. time left: 00:00:00:03
# 90.0%. Run time:  13.89s. Est. time left: 00:00:00:01
# 100.0%. Run time:  15.31s. Est. time left: 00:00:00:00
# Total run time:  15.32s
# The rotation angle is 0.0 pi
# Pi pulse amp is  0.1288957358306925 V
# The Excited State DAC is 1.01
# The Ground State DAC is 0.01
# info successly stored
# 22.1 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
from qutip.solver import Options
options = Options()
print(options)
# Out:
# Options:
# -----------
# atol:              1e-08
# rtol:              1e-06
# method:            adams
# order:             12
# nsteps:            1000
# first_step:        0
# min_step:          0
# max_step:          0
# tidy:              True
# num_cpus:          12
# norm_tol:          0.001
# norm_steps:        5
# rhs_filename:      None
# rhs_reuse:         False
# seeds:             0
# rhs_with_state:    False
# average_expect:    True
# average_states:    False
# ntraj:             500
# store_states:      False
# store_final_state: False
